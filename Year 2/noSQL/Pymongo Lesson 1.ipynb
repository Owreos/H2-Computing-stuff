# %% [markdown]
# ## Using Pymongo Lesson 1
#
# #### Installing pyMongo in jupyter notebook (if you have not installed)
#
# Using pip : !pip install pymongo==3.13.0
#
# For anaconda : open anaconda prompt, type conda install -c anaconda pymongo
#
# #### Import the books json files to the mongoDB server (if you have not import)
#
# * Start the mongoDB server
# * Check that there are no existing bookdb database
# * Remove any bookdb database if it exists
# * Use `monoimport` to import the books.json file into the mongoDB server.
#
# ```
#     mongoimport --db bookdb --collection book --file c:\data\books.json
# ```
#
# #### Connect to the MongoDB instance using pymongo
# Before you can start querying the data on your MongoDB instance, you need to connect to the MongoDB instance.
#
# ```
# ##import pymongo
# from pymongo import MongoClient
# client = MongoClient('localhost', 27017)
# ```
# #### Task 1
# List the databases in your MongoDB server.

# %%
from pymongo import MongoClient

client = MongoClient("127.0.0.1", 27017)

# %% [markdown]
# #### Check that you're connected
#
# To confirm that you're connected to a MongoDB server, and to get information about the server you're connected to,
# run
# ```
# client.server_info()
# ```
# #### Task 2
# Get information of the MongoDB server.

# %%
client.server_info()
# Out:
# {'version': '3.4.9',
#  'gitVersion': '876ebee8c7dd0e2d992f36a848ff4dc50ee6603e',
#  'targetMinOS': 'Windows 7/Windows Server 2008 R2',
#  'modules': [],
#  'allocator': 'tcmalloc',
#  'javascriptEngine': 'mozjs',
#  'sysInfo': 'deprecated',
#  'versionArray': [3, 4, 9, 0],
#  'openssl': {'running': 'OpenSSL 1.0.1u-fips  22 Sep 2016',
#   'compiled': 'OpenSSL 1.0.1u-fips  22 Sep 2016'},
#  'buildEnvironment': {'distmod': '2008plus-ssl',
#   'distarch': 'x86_64',
#   'cc': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.00.24223 for x64',
#   'ccflags': '/nologo /EHsc /W3 /wd4355 /wd4800 /wd4267 /wd4244 /wd4290 /wd4068 /wd4351 /we4013 /we4099 /we4930 /Z7 /errorReport:none /MD /O2 /Oy- /bigobj /Gw /Gy /Zc:inline',
#   'cxx': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.00.24223 for x64',
#   'cxxflags': '/TP',
#   'linkflags': '/nologo /DEBUG /INCREMENTAL:NO /LARGEADDRESSAWARE /OPT:REF',
#   'target_arch': 'x86_64',
#   'target_os': 'windows'},
#  'bits': 64,
#  'debug': False,
#  'maxBsonObjectSize': 16777216,
#  'storageEngines': ['devnull', 'ephemeralForTest', 'mmapv1', 'wiredTiger'],
#  'ok': 1.0}

# %% [markdown]
# #### Print a list of all the databases on this MongoDB instance
# Now that you’ve connected to a MongoDB instance, let’s explore the data stored on it.
#
# A single instance of MongoDB can support multiple independent databases. When you're connecting to a MongoDB instance for the first time, it can be helpful to check all the databases that are on the instance.
#
# An example of how this can be achieved is as follows:
#
# ```
# # Import the pprint method from the native Python pprint library
# from pprint import pprint
#
# for db in client.list_database_names(): ##list_database_names() returns a list of database names in MongoDB server
#     pprint(db)
# ```
#
# #### Task 3
# Printout the list of databases in the MongoDB server.

# %%
from pprint import pprint
for db in client.list_database_names():
    pprint(db)
# Out:
# 'admin'
# 'local'

# %% [markdown]
# #### Creating Collection
#
# In the example below, we will query the `customers` collection in the `mydatabase` database. We find the number of documents in the `customers` collection.
#
# ```
# db = client.mydatabase
# db.customers.count_documents({})
# ```
# #### Task 4
# Find the number of documents in the `customers` collection in the `mydatabase` database.

# %%
db = client.mydatabase
db.customers.count_documents({})
# Out:
# 0

# %% [markdown]
# #### Dropping Collection
#
# Sometime it is useful to drop a collection to 'redo' your task. The example below, we use the `drop()` method to drop the `customers` collection
#
# ```
# db.customers.drop()
# ```
#
# #### Using json module to read json file and load the data to MongoDB
#
#    Run the example below to
#
# ```
# bookdb = client["bookdb"]   ## another way to use the database
# coll = bookdb["book"]    ## another way to get the books collection in bookdb database
# with open('books.json') as jsonfile:
#     documents = json.load(jsonfile)
#     result=coll.insert_many(documents)
#
# ```
# #### Task 5
# Download the `books.json` file and load the documents to the `book` collection of the `bookdb` database.
# Find the number of documents in the `book` collection after the data has been loaded.

# %%
import json
db.customers.drop()


bookdb = client["bookdb"]
coll = bookdb["book"]
with open('books.json') as jsonfile:
    documents = json.load(jsonfile)
    res = coll.insert_many(documents)
# Out:
# ---------------------------------------------------------------------------
# BulkWriteError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35416\3276741674.py in <module>
#       7 with open('books.json') as jsonfile:
#       8     documents = json.load(jsonfile)
# ----> 9     res = coll.insert_many(documents)
#      10
#
# c:\Users\oscar\Desktop\vscode\Computing\.venv\lib\site-packages\pymongo\collection.py in insert_many(self, documents, ordered, bypass_document_validation, session)
#     813         blk = _Bulk(self, ordered, bypass_document_validation)
#     814         blk.ops = [doc for doc in gen()]
# --> 815         blk.execute(write_concern, session=session)
#     816         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#     817
#
# c:\Users\oscar\Desktop\vscode\Computing\.venv\lib\site-packages\pymongo\bulk.py in execute(self, write_concern, session)
#     555                 self.execute_no_results(sock_info, generator)
#     556         else:
# --> 557             return self.execute_command(generator, write_concern, session)
#     558
#     559
#
# c:\Users\oscar\Desktop\vscode\Computing\.venv\lib\site-packages\pymongo\bulk.py in execute_command(self, generator, write_concern, session)
#     368
#     369         if full_result["writeErrors"] or full_result["writeConcernErrors"]:
# --> 370             _raise_bulk_write_error(full_result)
#     371         return full_result
#     372
#
# c:\Users\oscar\Desktop\vscode\Computing\.venv\lib\site-packages\pymongo\bulk.py in _raise_bulk_write_error(full_result)
#     140     if full_result["writeErrors"]:
#     141         full_result["writeErrors"].sort(key=lambda error: error["index"])
# --> 142     raise BulkWriteError(full_result)
#     143
#     144
#
# BulkWriteError: batch op errors occurred, full error: {'writeErrors': [{'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: bookdb.book index: _id_ dup key: { : 1 }', 'op': {'_id': 1, 'title': 'Unlocking Android', 'isbn': '1933988673', 'pageCount': 416, 'publishedDate': {'$date': '2009-04-01T00:00:00.000-0700'}, 'thumbnailUrl': 'https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ.book-thumb-images/ableson.jpg', 'shortDescription': "Unlocking Android: A Developer's Guide provides concise, hands-on instruction for the Android operating system and development tools. This book teaches important architectural concepts in a straightforward writing style and builds on this with practical and useful examples throughout.", 'longDescription': "Android is an open source mobile phone platform based on the Linux operating system and developed by the Open Handset Alliance, a consortium of over 30 hardware, software and telecom companies that focus on open standards for mobile devices. Led by search giant, Google, Android is designed to deliver a better and more open and cost effective mobile experience.    Unlocking Android: A Developer's Guide provides concise, hands-on instruction for the Android operating system and development tools. This book teaches important architectural concepts in a straightforward writing style and builds on this with practical and useful examples throughout. Based on his mobile development experience and his deep knowledge of the arcane Android technical documentation, the author conveys the know-how you need to develop practical applications that build upon or replace any of Androids features, however small.    Unlocking Android: A Developer's Guide prepares the reader to embrace the platform in easy-to-understand language and builds on this foundation with re-usable Java code examples. It is ideal for corporate and hobbyists alike who have an interest, or a mandate, to deliver software functionality for cell phones.    WHAT'S INSIDE:        * Android's place in the market      * Using the Eclipse environment for Android development      * The Intents - how and why they are used      * Application classes:            o Activity            o Service            o IntentReceiver       * User interface design      * Using the ContentProvider to manage data      * Persisting data with the SQLite database      * Networking examples      * Telephony applications      * Notification methods      * OpenGL, animation & multimedia      * Sample Applications  ", 'status': 'PUBLISH', 'authors': ['W. Frank Ableson', 'Charlie Collins', 'Robi Sen'], 'categories': ['Open Source', 'Mobile']}}], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 0, 'nMatched': 0, 'nModified': 0, 'nRemoved': 0, 'upserted': []}
