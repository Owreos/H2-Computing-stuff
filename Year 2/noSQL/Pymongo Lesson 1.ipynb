# %% [markdown]
# ## Using Pymongo Lesson 1
#
# #### Installing pyMongo in jupyter notebook (if you have not installed)
#
# Using pip : !pip install pymongo==3.13.0
#
# For anaconda : open anaconda prompt, type conda install -c anaconda pymongo
#
# #### Import the books json files to the mongoDB server (if you have not import)
#
# * Start the mongoDB server
# * Check that there are no existing bookdb database
# * Remove any bookdb database if it exists
# * Use `monoimport` to import the books.json file into the mongoDB server.
#
# ```
#     mongoimport --db bookdb --collection book --file c:\data\books.json
# ```
#
# #### Connect to the MongoDB instance using pymongo
# Before you can start querying the data on your MongoDB instance, you need to connect to the MongoDB instance.
#
# ```
# ##import pymongo
# from pymongo import MongoClient
# client = MongoClient('localhost', 27017)
# ```
# #### Task 1
# List the databases in your MongoDB server.

# %%
from pymongo import MongoClient
client = MongoClient("127.0.0.1", 27017)

# %% [markdown]
# #### Check that you're connected
#
# To confirm that you're connected to a MongoDB server, and to get information about the server you're connected to,
# run
# ```
# client.server_info()
# ```
# #### Task 2
# Get information of the MongoDB server.

# %%
client.server_info()
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 client.server_info()
#
# File /workspaces/H2-Computing/.venv/lib/python3.14/site-packages/pymongo/mongo_client.py:2086, in MongoClient.server_info(self, session)
#    2076 def server_info(self, session=None):
#    2077     """Get information about the MongoDB server we're connected to.
#    2078
#    2079     :Parameters:
#    (...)   2084        Added ``session`` parameter.
#    2085     """
# -> 2086     return self.admin.command(
#    2087         "buildinfo", read_preference=ReadPreference.PRIMARY, session=session
#    2088     )
#
# File /workspaces/H2-Computing/.venv/lib/python3.14/site-packages/pymongo/database.py:827, in Database.command(self, command, value, check, allowable_errors, read_preference, codec_options, session, **kwargs)
#     825 if read_preference is None:
#     826     read_preference = (session and session._txn_read_preference()) or ReadPreference.PRIMARY
# --> 827 with self.__client._socket_for_reads(read_preference, session) as (sock_info, secondary_ok):
#     828     return self._command(
#     829         sock_info,
#     830         command,
#    (...)    838         **kwargs
#     839     )
#
# File /usr/local/lib/python3.14/contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     139 del self.args, self.kwds, self.func
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#     143     raise RuntimeError("generator didn't yield") from None
#
# File /workspaces/H2-Computing/.venv/lib/python3.14/site-packages/pymongo/mongo_client.py:1478, in MongoClient._socket_for_reads(self, read_preference, session)
#    1476 topology = self._get_topology()
#    1477 single = topology.description.topology_type == TOPOLOGY_TYPE.Single
# -> 1478 server = self._select_server(read_preference, session)
#    1480 with self._get_socket(server, session) as sock_info:
#    1481     secondary_ok = (single and not sock_info.is_mongos) or (
#    1482         read_preference != ReadPreference.PRIMARY
#    1483     )
#
# File /workspaces/H2-Computing/.venv/lib/python3.14/site-packages/pymongo/mongo_client.py:1436, in MongoClient._select_server(self, server_selector, session, address)
#    1434             raise AutoReconnect("server %s:%d no longer available" % address)
#    1435     else:
# -> 1436         server = topology.select_server(server_selector)
#    1437     return server
#    1438 except PyMongoError as exc:
#    1439     # Server selection errors in a transaction are transient.
#
# File /workspaces/H2-Computing/.venv/lib/python3.14/site-packages/pymongo/topology.py:250, in Topology.select_server(self, selector, server_selection_timeout, address)
#     248 def select_server(self, selector, server_selection_timeout=None, address=None):
#     249     """Like select_servers, but choose a random server if several match."""
# --> 250     return random.choice(self.select_servers(selector, server_selection_timeout, address))
#
# File /workspaces/H2-Computing/.venv/lib/python3.14/site-packages/pymongo/topology.py:211, in Topology.select_servers(self, selector, server_selection_timeout, address)
#     208     server_timeout = server_selection_timeout
#     210 with self._lock:
# --> 211     server_descriptions = self._select_servers_loop(selector, server_timeout, address)
#     213     return [self.get_server_by_address(sd.address) for sd in server_descriptions]
#
# File /workspaces/H2-Computing/.venv/lib/python3.14/site-packages/pymongo/topology.py:226, in Topology._select_servers_loop(self, selector, timeout, address)
#     223 while not server_descriptions:
#     224     # No suitable servers.
#     225     if timeout == 0 or now > end_time:
# --> 226         raise ServerSelectionTimeoutError(
#     227             "%s, Timeout: %ss, Topology Description: %r"
#     228             % (self._error_message(selector), timeout, self.description)
#     229         )
#     231     self._ensure_opened()
#     232     self._request_check_all()
#
# ServerSelectionTimeoutError: 127.0.0.1:27017: [Errno 111] Connection refused, Timeout: 30s, Topology Description: <TopologyDescription id: 69beb34e8561f92b07055923, topology_type: Single, servers: [<ServerDescription ('127.0.0.1', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('127.0.0.1:27017: [Errno 111] Connection refused')>]>

# %% [markdown]
# #### Print a list of all the databases on this MongoDB instance
# Now that you’ve connected to a MongoDB instance, let’s explore the data stored on it.
#
# A single instance of MongoDB can support multiple independent databases. When you're connecting to a MongoDB instance for the first time, it can be helpful to check all the databases that are on the instance.
#
# An example of how this can be achieved is as follows:
#
# ```
# # Import the pprint method from the native Python pprint library
# from pprint import pprint
#
# for db in client.list_database_names(): ##list_database_names() returns a list of database names in MongoDB server
#     pprint(db)
# ```
#
# #### Task 3
# Printout the list of databases in the MongoDB server.

# %% [markdown]
# #### Creating Collection
#
# In the example below, we will query the `customers` collection in the `mydatabase` database. We find the number of documents in the `customers` collection.
#
# ```
# db = client.mydatabase
# db.customers.count_documents({})
# ```
# #### Task 4
# Find the number of documents in the `customers` collection in the `mydatabase` database.

# %% [markdown]
# #### Dropping Collection
#
# Sometime it is useful to drop a collection to 'redo' your task. The example below, we use the `drop()` method to drop the `customers` collection
#
# ```
# db.customers.drop()
# ```
#
# #### Using json module to read json file and load the data to MongoDB
#
#    Run the example below to
#
# ```
# bookdb = client["bookdb"]   ## another way to use the database
# coll = bookdb["book"]    ## another way to get the books collection in bookdb database
# with open('books.json') as jsonfile:
#     documents = json.load(jsonfile)
#     result=coll.insert_many(documents)
#
# ```
# #### Task 5
# Download the `books.json` file and load the documents to the `book` collection of the `bookdb` database.
# Find the number of documents in the `book` collection after the data has been loaded.
